# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
 
# create data
x = ['A', 'B', 'C', 'D']
y1 = np.array([10, 20, 10, 30])
y2 = np.array([20, 25, 15, 25])
y3 = np.array([12, 15, 19, 6])
y4 = np.array([10, 29, 13, 19])
 
# plot bars in stack manner
fig, ax = plt.subplots(figsize=(6,4), dpi=100)

ax.bar(x, y1, color='deepskyblue')
ax.bar(x, y2, bottom=y1, color='deeppink')
ax.bar(x, y3, bottom=y1+y2, color='gold')
ax.bar(x, y4, bottom=y1+y2+y3, color='lime')

ax.set_xlabel("Teams", weight = 'bold')
ax.set_ylabel("Score", weight = 'bold')
ax.legend(["Round 1", "Round 2", "Round 3", "Round 4"])
ax.set_title("Scores by Teams in 4 Rounds")

for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(3)
    ax.spines[axis].set_color('k')
    ax.spines[axis].set_zorder(1)

plt.xticks(weight = 'bold')
plt.yticks(weight = 'bold')

plt.show()
